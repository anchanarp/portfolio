# %% [markdown]
# <a href="https://colab.research.google.com/github/anchanarp/PROJECT_ICT/blob/main/internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add_expense():
    try:
        category = input("Enter category (Food/Travel/etc): ")
        amount = float(input("Enter amount: "))

        with open("expenses.txt", "a") as file:
            file.write(f"{category},{amount}\n")

        print("Expense added successfully")

    except ValueError:
        print("Invalid amount! Please enter a number")


def view_expenses():
    try:
        with open("expenses.txt", "r") as file:
            print("\n--- All Expenses ---")
            for line in file:
                category, amount = line.strip().split(",")
                print(f"Category: {category} | Amount: {amount}")

    except FileNotFoundError:
        print("No expenses found! File does not exist")


def calculate_total():
    try:
        total = 0
        with open("expenses.txt", "r") as file:
            for line in file:
                _, amount = line.strip().split(",")
                total += float(amount)

        print(f"\nTotal Expense: {total}")

    except FileNotFoundError:
        print("No expenses to calculate")


def category_count():
    try:
        counts = {}
        with open("expenses.txt", "r") as file:
            for line in file:
                category, _ = line.strip().split(",")
                counts[category] = counts.get(category, 0) + 1

        print("\n--- Category Count ---")
        for cat, count in counts.items():
            print(f"{cat}: {count}")

    except FileNotFoundError:
        print("No data found")

while True:
    print("\n---Expense Tracker---")
    print("1. Add Expense")
    print("2. View Expenses")
    print("3. Total Expense")
    print("4. Category Count")
    print("5. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_expense()
    elif choice == "2":
        view_expenses()
    elif choice == "3":
        calculate_total()
    elif choice == "4":
        category_count()
    elif choice == "5":
        print("Exiting")
        break
    else:
        print("Invalid choice")
# Out:
# ----- Expense Tracker -----
# 1. Add Expense
# 2. View Expenses
# 3. Total Expense
# 4. Category Count
# 5. Exit
# Enter your choice: 1
# Enter category (Food/Travel/etc): shopping
# Enter amount: 500
# Expense added successfully
#
# ----- Expense Tracker -----
# 1. Add Expense
# 2. View Expenses
# 3. Total Expense
# 4. Category Count
# 5. Exit
# Enter your choice: 1
# Enter category (Food/Travel/etc): travel
# Enter amount: 2000
# Expense added successfully
#
# ----- Expense Tracker -----
# 1. Add Expense
# 2. View Expenses
# 3. Total Expense
# 4. Category Count
# 5. Exit
# Enter your choice: 1
# Enter category (Food/Travel/etc): food
# Enter amount: 200
# Expense added successfully
#
# ----- Expense Tracker -----
# 1. Add Expense
# 2. View Expenses
# 3. Total Expense
# 4. Category Count
# 5. Exit
# Enter your choice: 2
#
# --- All Expenses ---
# Category: food | Amount: 500.0
# Category: shopping | Amount: 500.0
# Category: travel | Amount: 2000.0
# Category: food | Amount: 200.0
# ...
